# %%
import pandas as pd

df = pd.read_csv("play_origins/sweden.csv", skiprows=1)

# %%
df
# Out:
#       Rk                         Player  From    To Pos    GP    G    A   PTS  \
# 0      1         Pontus Aberg\abergpo01  2017  2020  LW   130   17   27    44
# 1      2   Thommy Abrahamsson\abrahth01  1981  1981   D    32    6   11    17
# 2      3          Sebastian Aho\ahose02  2018  2018   D    22    1    3     4
# 3      4        Tommy Albelin\albelto01  1988  2006   D   952   44  211   255
# 4      5    Daniel Alfredsson\alfreda01  1996  2014  RW  1246  444  713  1157
# 5      6       Erik Andersson\anderer01  1998  1998   C    12    2    1     3
# 6      7     Joakim Andersson\anderjo03  2012  2016   C   205   15   21    36
# 7      8      Jonas Andersson\anderjo02  2002  2011  RW     9    0    0     0
# 8      9  Kent-Erik Andersson\anderke01  1978  1984  RW   456   72  103   175
# 9     10       Lias Andersson\anderli01  2018  2020   C    66    3    6     9
# 10    11     Mikael Andersson\andermi01  1986  2000  LW   761   95  169   264
# ...

# %%
df.describe()
# Out:
#                Rk         From           To           GP           G  \
# count  347.000000   347.000000   347.000000   347.000000  347.000000
# mean   174.000000  2002.616715  2007.334294   281.394813   45.426513
# std    100.314505    13.859537    13.756262   316.274790   78.741893
# min      1.000000  1933.000000  1933.000000     1.000000    0.000000
# 25%     87.500000  1993.000000  1999.000000    32.000000    1.000000
# 50%    174.000000  2006.000000  2011.000000   150.000000    9.000000
# 75%    260.500000  2014.000000  2020.000000   485.000000   53.000000
# max    347.000000  2020.000000  2020.000000  1564.000000  564.000000
#
#                 A          PTS         +/-          PIM        GP.1  \
# count  347.000000   347.000000  346.000000   347.000000   28.000000
# mean    87.959654   133.386167    6.635838   138.017291  144.964286
# std    145.876179   218.858509   46.658491   239.405634  189.991322
# min      0.000000     0.000000  -86.000000     0.000000    1.000000
# ...
