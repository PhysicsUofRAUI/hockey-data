# %%
import pandas as pd

df = pd.read_csv("play_origins/finland.csv", skiprows=1)

# %%
df
# Out:
#       Rk                         Player  From    To Pos    GP    G    A  PTS  \
# 0      1          Antti Aalto\aaltoan01  1998  2001   C   151   11   17   28
# 1      2          Sebastian Aho\ahose01  2017  2020   F   288  106  131  237
# 2      3          Peter Ahola\aholape01  1992  1994   D   123   10   17   27
# 3      4     Sami Aittokallio\aittosa01  2013  2014   G     2    0    0    0
# 4      5         Mika Alatalo\alatami01  2000  2001  LW   152   17   29   46
# 5      6           Joel Armia\armiajo01  2015  2020  RW   272   51   51  102
# 6      7     Niklas Backstrom\backsni01  2007  2016   G   413    0    5    5
# 7      8    Aleksander Barkov\barkoal01  2014  2020   C   458  149  245  394
# 8      9              Aki Berg\bergak01  1996  2006   D   606   15   70   85
# 9     10      Sean Bergenheim\bergese01  2004  2015  LW   506   96   84  180
# 10    11       Timo Blomqvist\blomqti01  1982  1987   D   243    4   53   57
# ...

# %%
boxplot = df.boxplot(column="+/-")

# %%
df.describe()
# Out:
#                Rk         From           To           GP           G  \
# count  226.000000   226.000000   226.000000   226.000000  226.000000
# mean   113.500000  2002.314159  2006.309735   219.575221   35.809735
# std     65.384759    13.616443    13.577157   297.172537   82.831363
# min      1.000000  1927.000000  1927.000000     1.000000    0.000000
# 25%     57.250000  1995.250000  2000.250000    15.000000    0.000000
# 50%    113.500000  2004.000000  2009.000000    93.500000    4.000000
# 75%    169.750000  2014.000000  2019.000000   287.500000   30.250000
# max    226.000000  2020.000000  2020.000000  1451.000000  684.000000
#
#                 A          PTS         +/-          PIM        GP.1  \
# count  226.000000   226.000000  223.000000   226.000000   33.000000
# mean    63.814159    99.623894    1.466368   106.221239  163.333333
# std    126.258292   204.654387   36.910746   204.809710  202.481121
# min      0.000000     0.000000 -143.000000     0.000000    1.000000
# ...
